# %%
# !git clone https://github.com/Walid-Ahmed/PPE-YOLOV7.git
# Out:
# Cloning into 'PPE-YOLOV7'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 216 (delta 58), reused 109 (delta 57), pack-reused 103
# Receiving objects: 100% (216/216), 170.08 MiB | 46.62 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
# %cd PPE-YOLOV7
# !pip install -r requirements.txt

# %%
Run = -1

# %%
# !python detect.py --weights yolov7.pt --weights2 Helmet.pt --conf 0.3 --class 0  --object 0  --source TestVideo.mp4
Run+=1
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[0], conf_thres=0.3, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, objects=[0], project='runs/detect', save_conf=False, save_txt=False, source='TestVideo.mp4', update=False, view_img=False, weights=['yolov7.pt'], weights2=['Helmet.pt'])
# YOLOR 🚀 529c607 torch 1.12.1+cu113 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# # For Images:

# %%
if Run != 0 : 
    Folder = f'exp{Run}'
else:
    Folder = 'exp'
import glob
from IPython.display import Image, display
for imageName in glob.glob(f'/content/PPE-YOLOV7/runs/detect/{Folder}/*.png'): #assuming JPG
    display(Image(filename=imageName))
